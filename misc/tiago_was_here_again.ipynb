# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import networkx as nx
import pathlib

# %%
model_sate = torch.load("../saved_models/slgcn_global.pt", map_location=torch.device('cpu'))

def graph_plotter(A: np.ndarray, **draw_args):
    g = nx.convert_matrix.from_numpy_matrix(A)
    nx.draw(g, node_size=50, **draw_args)
    plt.show()

def get_weights(A):
    G = nx.from_numpy_array(A)
    weights = nx.get_edge_attributes(G, "weight").values()
    return list(weights)

# %%
plt.figure(figsize=(10,10))
ws0 = np.array(model_sate["g_layer_list.0.ws"])
plt.imshow(ws0)

# %%
place = "metr_la"
place_path = pathlib.Path("../data")/place
pos = np.load(place_path/f'pos_{place.split("_")[1]}.npy')
graph_plotter(ws0, width = get_weights(ws0), pos=pos)

# %%
plt.figure(figsize=(10,10))
ws1 = np.array(model_sate["g_layer_list.1.ws"])
plt.imshow(ws1)

# %%
place = "metr_la"
place_path = pathlib.Path("../data")/place
pos = np.load(place_path/f'pos_{place.split("_")[1]}.npy')
graph_plotter(ws1, width = get_weights(ws1), pos=pos)

# %%
plt.figure(figsize=(10,10))
last_ws = np.array(model_sate["g_last.ws"])
plt.imshow(last_ws)

# %%
place = "metr_la"
place_path = pathlib.Path("../data")/place
pos = np.load(place_path/f'pos_{place.split("_")[1]}.npy')
graph_plotter(last_ws, width = get_weights(last_ws), pos=pos)
