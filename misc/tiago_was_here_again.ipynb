# %%
import torch
from matplotlib import pyplot as plt

# %%
model_sate = torch.load("../saved_models/model_002.pt", map_location=torch.device('cpu'))

# %%
model_sate
# Out:
# OrderedDict([('g_last.ws',
#               tensor([[ 0.0271,  0.0031,  0.0005,  ...,  0.0014,  0.0040,  0.0030],
#                       [ 0.0037,  0.0010,  0.0031,  ...,  0.0019,  0.0060,  0.0028],
#                       [ 0.0016,  0.0043,  0.0090,  ...,  0.0034,  0.0037, -0.0002],
#                       ...,
#                       [ 0.0026,  0.0040,  0.0048,  ...,  0.0006,  0.0010,  0.0018],
#                       [ 0.0058,  0.0044,  0.0015,  ...,  0.0011,  0.0009,  0.0022],
#                       [ 0.0013,  0.0028,  0.0016,  ...,  0.0029,  0.0020,  0.0249]])),
#              ('g_last.wp',
#               tensor([[ 4.8872e-06, -6.7808e-07,  3.3207e-08,  ..., -4.2842e-07,
#                        -7.2571e-07, -5.6588e-07],
#                       [-3.4114e-07, -3.3018e-07,  5.0419e-08,  ...,  7.0787e-07,
#                         1.8102e-07,  1.5817e-07],
#                       [-1.3491e-06, -1.2295e-06,  6.6999e-09,  ..., -1.5490e-07,
# ...

# %%
plt.figure(figsize=(10,10))
plt.imshow(model_sate["g_last.ws"])

# %%
plt.figure(figsize=(10,10))
plt.imshow(model_sate["g_last.wp"])
