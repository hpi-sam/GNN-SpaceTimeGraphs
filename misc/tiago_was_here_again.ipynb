# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
losses = np.load("../losses_on_100_epochs.npy")

# %%
plt.plot(np.arange(100), losses)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss\n GCN Only")
plt.savefig("../img/training_loss_gcn2.png")
